# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Dataset
data = {
    "st_id": [101, 102, 103, 104, 105],
    "student_name": ["Rahul", "Priya", "Aman", "Neha", "Rohit"],
    "study_hours": [5, 7, 3, 8, 6],
    "attendance": [85, 92, 70, 95, 88],
    "result": ["Pass", "Pass", "Fail", "Pass", "Pass"]
}

df = pd.DataFrame(data)

print(df)

# Matplotlib
plt.figure(figsize=(8, 5))
plt.bar(df["student_name"], df["study_hours"])
plt.xlabel("Student Name")
plt.ylabel("Study Hours")
plt.title("Student Study Hours")
plt.show()

# Seaborn
plt.figure(figsize=(8, 5))
sns.scatterplot(
    x="study_hours",
    y="attendance",
    data=df,
    hue="result",
    s=100
)
plt.title("Study Hours vs Attendance")
plt.xlabel("Study Hours")
plt.ylabel("Attendance (%)")
plt.show()

# Seaborn count plot
plt.figure(figsize=(6, 4))
sns.countplot(x="result", data=df)
plt.title("Pass vs Fail Students")
plt.show()
# Out:
#    st_id student_name  study_hours  attendance result
# 0    101        Rahul            5          85   Pass
# 1    102        Priya            7          92   Pass
# 2    103         Aman            3          70   Fail
# 3    104         Neha            8          95   Pass
# 4    105        Rohit            6          88   Pass
